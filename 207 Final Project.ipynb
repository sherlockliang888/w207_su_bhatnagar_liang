# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("~/Desktop/fake_job_postings.csv")
df
# Out:
#        job_id                                              title  \
# 0           1                                   Marketing Intern
# 1           2          Customer Service - Cloud Video Production
# 2           3            Commissioning Machinery Assistant (CMA)
# 3           4                  Account Executive - Washington DC
# 4           5                                Bill Review Manager
# ...       ...                                                ...
# 17875   17876                   Account Director - Distribution
# 17876   17877                                 Payroll Accountant
# 17877   17878  Project Cost Control Staff Engineer - Cost Con...
# 17878   17879                                   Graphic Designer
# 17879   17880                         Web Application Developers
#
#                    location   department salary_range  \
# 0          US, NY, New York    Marketing          NaN
# 1            NZ, , Auckland      Success          NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17880 entries, 0 to 17879
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   job_id               17880 non-null  int64
#  1   title                17880 non-null  object
#  2   location             17534 non-null  object
#  3   department           6333 non-null   object
#  4   salary_range         2868 non-null   object
#  5   company_profile      14572 non-null  object
#  6   description          17879 non-null  object
#  7   requirements         15185 non-null  object
#  8   benefits             10670 non-null  object
#  9   telecommuting        17880 non-null  int64
#  10  has_company_logo     17880 non-null  int64
#  11  has_questions        17880 non-null  int64
#  12  employment_type      14409 non-null  object
#  13  required_experience  10830 non-null  object
#  14  required_education   9775 non-null   object
# ...

# %%
len(df['function'].unique())
# Out:
# 38

# %%
# drop department because of many missing values, drop first couple of columns because they are too descriptive and varied
df=df.drop(["department","job_id","title","location","salary_range","company_profile","description","requirements","benefits"],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17880 entries, 0 to 17879
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   telecommuting        17880 non-null  int64
#  1   has_company_logo     17880 non-null  int64
#  2   has_questions        17880 non-null  int64
#  3   employment_type      14409 non-null  object
#  4   required_experience  10830 non-null  object
#  5   required_education   9775 non-null   object
#  6   industry             12977 non-null  object
#  7   function             11425 non-null  object
#  8   fraudulent           17880 non-null  int64
# dtypes: int64(4), object(5)
# memory usage: 1.2+ MB

# %%
df=df.dropna()

# %%
df
# Out:
#        telecommuting  has_company_logo  has_questions employment_type  \
# 3                  0                 1              0       Full-time
# 4                  0                 1              1       Full-time
# 6                  0                 1              1       Full-time
# 9                  0                 1              0       Part-time
# 10                 0                 0              0       Full-time
# ...              ...               ...            ...             ...
# 17867              0                 1              0       Full-time
# 17870              0                 1              1       Full-time
# 17874              0                 0              0       Full-time
# 17876              0                 1              1       Full-time
# 17878              0                 0              1        Contract
#
#       required_experience         required_education  \
# 3        Mid-Senior level          Bachelor's Degree
# ...

# %%
one_hot_encoded_data = pd.get_dummies(df, columns = ['employment_type', 'required_experience',"required_education","industry","function"]) 
one_hot_encoded_data.columns
# Out:
# Index(['telecommuting', 'has_company_logo', 'has_questions', 'fraudulent',
#        'employment_type_Contract', 'employment_type_Full-time',
#        'employment_type_Other', 'employment_type_Part-time',
#        'employment_type_Temporary', 'required_experience_Associate',
#        ...
#        'function_Public Relations', 'function_Purchasing',
#        'function_Quality Assurance', 'function_Research', 'function_Sales',
#        'function_Science', 'function_Strategy/Planning',
#        'function_Supply Chain', 'function_Training',
#        'function_Writing/Editing'],
#       dtype='object', length=195)

# %%
df_final=one_hot_encoded_data

# %%
df_final['fraudulent'].value_counts()
# Out:
# 0    7273
# 1     342
# Name: fraudulent, dtype: int64

# %% [markdown]
# # Baseline model accuracy

# %%
# assume model only returns 0 for all inputs, accuracy is:
7273/(7273+342)
# Out:
# 0.9550886408404465

# %% [markdown]
# # Train test split

# %%
from sklearn.model_selection import train_test_split 
import sklearn

X= df_final.drop(['fraudulent'],axis=1) 
y=df['fraudulent'] 
  
# using the train test split function 
X_train, X_test, y_train, y_test = train_test_split(X,y , 
                                   random_state=104,  
                                   test_size=0.20,  
                                   shuffle=True)

# %%
from sklearn.linear_model import LogisticRegression 
from sklearn import metrics 

logreg =  LogisticRegression(solver='liblinear') 
# fit the model with data 
logreg.fit(X_train,y_train) 

# predicting 
y_pred=logreg.predict(X_test) 
print("Accuracy:",metrics.accuracy_score(y_test, y_pred)) 

print("Precision:",metrics.precision_score(y_test, y_pred)) 

print("Recall:",metrics.recall_score(y_test, y_pred))
# Out:
# Accuracy: 0.9606040709126723
# Precision: 0.7857142857142857
# Recall: 0.16176470588235295

# %%
X_train
# Out:
#        telecommuting  has_company_logo  has_questions  \
# 12776              0                 1              1
# 1696               0                 1              0
# 53                 0                 0              0
# 10088              0                 1              0
# 911                0                 1              1
# ...              ...               ...            ...
# 1389               0                 1              1
# 12076              0                 1              1
# 1558               0                 1              1
# 13151              0                 1              1
# 136                0                 1              0
#
#        employment_type_Contract  employment_type_Full-time  \
# 12776                         0                          1
# 1696                          0                          1
# 53                            0                          1
# 10088                         0                          1
# ...

# %%
print(logreg.coef_)
# Out:
# [[-0.02045584 -1.72094742  0.40406247 -0.05789696 -0.33778581  0.42310486
#   -0.78670691 -0.93249282 -0.75142317  0.39636293 -0.31622843 -0.4200733
#   -0.25964725 -0.13838755 -0.20238086 -0.27199756 -0.74734036  0.71469484
#    0.31057167  0.35592607  0.2071596  -0.48371067 -0.03295112 -0.41680456
#   -0.24133554 -0.81082148 -0.07367426 -0.20149426  2.13638501  0.16717343
#    0.          0.         -0.46629703 -0.06181143  0.02602562 -0.32314507
#   -0.65117334  1.2172144   0.70787493 -0.2484429   0.45342371 -0.1924176
#   -0.42360772 -0.40903084  0.38180686 -0.03047087  1.51907134 -0.52458749
#    0.64930955  2.52951131 -1.31447932 -0.87509338 -0.54411209 -0.1841999
#    0.56304648  0.44416905  0.7441207   0.48636978 -0.88376255 -1.25592116
#    0.19484376  0.72297474  0.60322394 -0.70070881  0.21739184 -0.45169219
#   -0.42925188 -0.04012784 -0.63901343  0.04523339 -0.16135593 -0.85113678
#   -0.48238726 -0.35300315 -0.26489171 -1.03858133 -0.20524558  0.06308653
# ...

# %% [markdown]
# # Feature selection

# %% [markdown]
# telecommuting dropped because of small weights

# %%
# drop deparment because of many missing values
df_final=df_final.drop(["telecommuting"],axis=1)

# %%
from sklearn.model_selection import train_test_split 
import sklearn

X= df_final.drop(['fraudulent'],axis=1) 
y=df['fraudulent'] 
  
# using the train test split function 
X_train, X_test, y_train, y_test = train_test_split(X,y , 
                                   random_state=104,  
                                   test_size=0.20,  
                                   shuffle=True) 
from sklearn.linear_model import LogisticRegression 
from sklearn import metrics 

logreg =  LogisticRegression(solver='liblinear') 
# fit the model with data 
logreg.fit(X_train,y_train) 

# predicting 
y_pred=logreg.predict(X_test) 
print("Accuracy:",metrics.accuracy_score(y_test, y_pred)) 

print("Precision:",metrics.precision_score(y_test, y_pred)) 

print("Recall:",metrics.recall_score(y_test, y_pred))
# Out:
# Accuracy: 0.9606040709126723
# Precision: 0.7857142857142857
# Recall: 0.16176470588235295

# %% [markdown]
# # Model selection

# %%
# Create Decision Tree classifer object
from sklearn.tree import DecisionTreeClassifier 
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9704530531845043

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
accuracy = metrics.accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9763624425476034
